# %% [markdown]
# <a href="https://colab.research.google.com/github/mashabiarya/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray')

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(18,500),fontFace=font,fontScale=4,color=( 255, 255,0) ,thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True, color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
img6 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img6[10:100, 10:100])

# %%
img_RedGreen = img.copy()
img_RedGreen [:,:,2] = 0
plt.imshow(img_RedGreen)

# %%
img_GreenBlue = img.copy()
img_GreenBlue [:,:,0] = 0
plt.imshow(img_GreenBlue)

# %%
img6 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img6[5:30])

# %%
img6 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
for y in range (5):

  start = rand.randint(0,600)
  end = rand.randint(0,600)

  c1 = rand.randint(0,255)
  c2 = rand.randint(0,255)
  c3 = rand.randint(0,255)

  startp = (start,start)
  endp = (end,end)

  color = (c1,c2,c3)

  img6 = cv.rectangle(img3, startp, endp, color, thickness=3)

plt.imshow(img6)

# %%
img3 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
plt.imshow(img3)

# %%
img10 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img10,pt1=(300,100),pt2=(500,270),color=(255,0,),thickness=15)
plt.imshow(img10)
cv.circle(img10,center=(400,200),radius=100,color=(0,255,0),thickness=8)
plt.imshow(img10)

# %%
cv.rectangle(img10,pt1=(10,550),pt2=(200,500),color=(255,255,255),thickness=5)
plt.imshow(img10)
