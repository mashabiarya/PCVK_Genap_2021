# %% [markdown]
# <a href="https://colab.research.google.com/github/mashabiarya/PCVK_Genap_2021/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
print(' Mengubah tingkat kecerahan citra')
print('---------------------------------')
try:
    brightness = int(input('Masukkan nilai kecerahan: '))
except ValueError:
    print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PCVK/images/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

#akses per piksel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
#  Mengubah tingkat kecerahan citra
# ---------------------------------
# Masukkan nilai kecerahan: 50
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F4FFA0833D0>

# %%
image = cv.imread('/content/drive/MyDrive/PCVK/images/female.tiff')
image2 = np.zeros(image.shape, image.dtype)

print(' Mengubah kontras dan tingkat kecerahan citra') 
print('---------------------------------') 
try: 
    brightness = int(input('Masukkan tingkat kecerahan[-255 - 255]: '))
    contrast = float(input('Masukkan kontras [1.0-3.0]: ')) 
except ValueError: 
    print('Error, not a number') 
 
for y in range(image2.shape[0]):
  for x in range(image2.shape[1]):
    for c in range(image2.shape[2]): 
            image2[y,x,c] = np.clip(contrast*image[y,x,c] + brightness,
0, 255)
cv2_imshow(image) 
cv2_imshow(image2)
# Out:
#  Mengubah kontras dan tingkat kecerahan citra
# ---------------------------------
# Masukkan tingkat kecerahan[-255 - 255]: 60
# Masukkan kontras [1.0-3.0]: 1.5
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F4FF0703DD0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F4FF0703F50>

# %%
print(' -------------------------------- ')

try:
  brightness = int(input('Masukan nilai kecerahan: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PCVK/images/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(brightness*(np.log(1.0+original[y,x,c])), 0, 255)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
#  --------------------------------
# Masukan nilai kecerahan: 40
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F4FF06ACA10>

# %%
imageavg = cv.imread('/content/drive/MyDrive/PCVK/images/mandrill.tiff')
imageavg[:] = imageavg.mean(axis=-1, keepdims=1)
plt.imshow(imageavg)

# %%
imagelight = cv.imread('/content/drive/MyDrive/PCVK/images/mandrill.tiff')
imagelight[:] = np.max(imagelight,axis=-1,keepdims=1)/2+np.min(imglight,axis=-1,keepdims=1)/2
plt.imshow(imagelight)

# %%
imagelum = cv.imread('/content/drive/MyDrive/PCVK/images/mandrill.tiff')
R, G, B = imagelum[:,:,0], imagelum[:,:,1], imagelum[:,:,2]

gray_imagelum = (0.21 * R) + (0.72 * G) + (0.07 * B)

plt.imshow(gray_imagelum, cmap='gray')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-f1ebfbd1f87e> in <module>()
#       3 for y in range(5):
#       4
# ----> 5   start = rand.randint(0,600)
#       6   end = rand.randint(0,600)
#       7   c1 = rand.randint(0,255)
#
# NameError: name 'rand' is not defined
